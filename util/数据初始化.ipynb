# %% [markdown]
# - 读取数据
# - 将数据进行下采样处理
# - 将处理完成的数据更名存储到对应文件夹中

# %% [markdown]
# 测试代码

# %%
import os

import imageio
import torch
import torch.nn as nn
import torchvision.transforms.functional as f

# %%
x =imageio.imread("IMG_0576.JPG")

# %%
x.shape
# Out:
# (969, 969, 3)

# %%
img = torch.from_numpy(x.transpose((2, 0, 1)))
batch = torch.stack([img]).float()

# %%
batch.shape
# Out:
# torch.Size([1, 3, 969, 969])

# %%
mg_x2 = nn.functional.interpolate(batch, scale_factor=0.5, mode='bilinear', align_corners=False)

# %%
import matplotlib.pyplot as plt
plt.imshow(mg_x2[0][0])

# %%
a = mg_x2.permute(0,2,3,1)

# %%
plt.imshow(a[0].int())

# %%
plt.imshow(x)

# %%
a[0].int
# Out:
# <function Tensor.int>

# %%
x =imageio.read("IMG_0576.JPG")

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-7ec70090fe48> in <module>
# ----> 1 plt.imshow(x)
#
# ~/anaconda3/envs/aaa/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2728         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2729         url=url, **({"data": data} if data is not None else {}),
# -> 2730         **kwargs)
#    2731     sci(__ret)
#    2732     return __ret
#
# ~/anaconda3/envs/aaa/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
# ...

# %%
imageio.imsave("imgx3.jpg",a[0])
# Out:
# Lossy conversion from float32 to uint8. Range [3.753373146057129, 255.00003051757812]. Convert image to uint8 prior to saving to suppress this warning.

# %%
x =imageio.imread("../data/IMG_0576.JPG")
img = torch.from_numpy(x.transpose((2, 0, 1)))
batch = torch.stack([img])
mg_x2 = nn.functional.interpolate(batch, scale_factor=0.5, mode='bilinear', align_corners=False)
a = mg_x2.permute(0, 2, 3, 1)
imageio.imsave("imgx4.jpg", a[0].int())
# Out:
# /var/folders/mk/g6m89spn3b78zhfrcfljng1w0000gn/T/ipykernel_15032/146483988.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   x =imageio.imread("../data/IMG_0576.JPG")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 4
#       2 img = torch.from_numpy(x.transpose((2, 0, 1)))
#       3 batch = torch.stack([img]).int()
# ----> 4 mg_x2 = nn.functional.interpolate(batch, scale_factor=0.5, mode='bilinear', align_corners=False)
#       5 a = mg_x2.permute(0, 2, 3, 1)
#       6 imageio.imsave("imgx4.jpg", a[0].int())
#
# ...

# %%
import os
os.listdir("../data")
imglist = [];
for i in os.listdir("../data"):
    imglist.append("../data"+"/"+i)
list(imglist)
# Out:
# ['../data/MNIST',
#  '../data/benchmark',
#  '../data/img_1.png',
#  '../data/iShot_2022-12-16_09.17.44.png',
#  '../data/IMG_0576X2.jpg',
#  '../data/result',
#  '../data/IMG_0576.JPG',
#  '../data/iShot_2023-02-04_22.29.12.png',
#  '../data/IMG_0576X4.jpg',
#  '../data/cifar-10-batches-py',
#  '../data/HDT',
#  '../data/img.png',
#  '../data/IMG_1177.jpg',
#  '../data/imgx3.jpg']

# %%
x = torch.randn(3,3,14,14)

# %%
for i in range(x.shape[0]):
    print(i)
# Out:
# 0
# 1
# 2

# %%
from PIL import Image

# %%
a =Image.open("../data/imgx3.jpg")

# %%
import torchvision
img = torchvision.transforms.functional.center_crop(a,(120,120))

# %%
imageio.imsave("cat.jpg",img)

# %%
x = []
x.append()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 x = []
# ----> 2 x.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
a.size
# Out:
# (484, 484)

# %%
a.size[1]
# Out:
# 484
